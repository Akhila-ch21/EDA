# %% [markdown]
# # Matplotlib

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

import os
path = '/Users/akhilachalamcharla/Desktop/Data Science_New'
os.chdir(path)
os.getcwd()
# Out:
# '/Users/akhilachalamcharla/Desktop/Data Science_New'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Importing sample dataset from kaggle - "Nutrition Facts for MC Donald's Menu"

df = pd.read_csv("menu.csv")
print(df.shape)
display(df.head(3))
print(df.columns)

# Getting the basic statistic metrics of data
display(df.describe(include ="all"))

# checking for null values
display(df.isna().sum())

# checking the unique values of category
print(df.Category.nunique(), df.Category.unique())
# Out:
# (260, 24)
#     Category               Item    Serving Size  Calories  Calories from Fat  \
# 0  Breakfast       Egg McMuffin  4.8 oz (136 g)       300                120
# 1  Breakfast  Egg White Delight  4.8 oz (135 g)       250                 70
# 2  Breakfast   Sausage McMuffin  3.9 oz (111 g)       370                200
#
#    Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0       13.0                         20            5.0
# 1        8.0                         12            3.0
# 2       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 0                             25        0.0  ...             31
# 1                             15        0.0  ...             30
# 2                             42        0.0  ...             29
#
#    Carbohydrates (% Daily Value)  Dietary Fiber  \
# 0                             10              4
# 1                             10              4
# ...

# %%
display(df["Sodium"].describe())
# Max sodium value = 3600.00

## Identify the index of the row associated with maximum sodium value (3600.00)
print("\nIndex of row with max sodium value:", df["Sodium"].idxmax())

print(df.at[82,"Item"])
# Out:
# count     260.000000
# mean      495.750000
# std       577.026323
# min         0.000000
# 25%       107.500000
# 50%       190.000000
# 75%       865.000000
# max      3600.000000
# Name: Sodium, dtype: float64
# Index of row with max sodium value: 82
# Chicken McNuggets (40 piece)

# %% [markdown]
# ## Scatter Plot

# %% [markdown]
# ### swarmplot - categorywise scatterplot

# %%
plot = sns.swarmplot(x = 'Category', y ='Sodium', data = df)

plt.title("Sodium Content")
#plt.xlabel("Category_name"); plt.ylabel("Sodium")

## X-axis lables are rotated at 70 degrees
plt.setp(plot.get_xticklabels(), rotation = 70)

plt.show()

# %% [markdown]
# ### Joint Plot - binary distribution

# %% [markdown]
# - Helps in identifying the "Correlation b/w two variable"

# %%
plot = sns.jointplot(x ="Protein", y ="Total Fat", data = df)
plt.show() # Positive Correlation b/w protein & Total Fat

# %% [markdown]
# ----

# %% [markdown]
# # Box Plot

# %% [markdown]
# - helps in identifying the outliers

# %%
plot = sns.set_style("whitegrid")
ax = sns.boxplot(x= df["Sugars"])
plt.show() # helps in identifying the outliers
